# %% [raw]
# ---
# description: Fill in a module description here
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(foo)
# Out:
# ---
#
# [source](https://github.com/chauck/nbdev_test/blob/main/nbdev_test/core.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### foo
#
# >      foo ()

# %%
#| echo: false
#| output: asis
show_doc(cell_with_export_directive)
# Out:
# ---
#
# ### cell_with_export_directive
#
# >      cell_with_export_directive ()

# %%
def cell_with_exports_directive():
    print("hi")
    print("ok")
    a = 1+2
    print(a)

# %%
#| echo: false
#| output: asis
show_doc(cell_with_exports_directive)
# Out:
# ---
#
# ### cell_with_exports_directive
#
# >      cell_with_exports_directive ()

# %%
def cell_without_directive():
    print("hi")
    print("ok")
    a = 1+3
    print(a)
